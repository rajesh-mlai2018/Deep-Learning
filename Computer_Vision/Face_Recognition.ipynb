# %%
#!pip install retina-face
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Created wheel for gdown: filename=gdown-4.4.0-py3-none-any.whl size=14775 sha256=754d37d66eafffc114fbc63755976d05847e1af22eb0f5adf052a24e82918b11
#   Stored in directory: c:\users\rparepal\appdata\local\pip\cache\wheels\7d\37\b6\b2a79c75e898c0b8e46ff255102602d7159a10d9af0d80641a
# Successfully built gdown
# ...

# %%
# !pip install deepface

# %%
from retinaface import RetinaFace

# %%
resp = RetinaFace.detect_faces("DSC_0003.JPG")
# Out:
# Directory  C:\Users\RPAREPAL /.deepface created
# Directory  C:\Users\RPAREPAL /.deepface/weights created
# retinaface.h5 will be downloaded from the url https://github.com/serengil/deepface_models/releases/download/v1.0/retinaface.h5
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/retinaface.h5
# To: C:\Users\RPAREPAL\.deepface\weights\retinaface.h5
# 100%|███████████████████████████████████████████████████████████████████████████████| 119M/119M [00:21<00:00, 5.43MB/s]

# %%
resp
# Out:
# {'face_1': {'score': 0.999687910079956,
#   'facial_area': [243, 130, 357, 270],
#   'landmarks': {'right_eye': [259.50183, 188.06262],
#    'left_eye': [304.74484, 178.36424],
#    'nose': [274.51776, 213.7073],
#    'mouth_right': [273.09982, 239.01997],
#    'mouth_left': [309.09344, 230.9936]}},
#  'face_2': {'score': 0.9993939399719238,
#   'facial_area': [420, 43, 509, 237],
#   'landmarks': {'right_eye': [437.32394, 124.16013],
#    'left_eye': [463.46466, 122.011444],
#    'nose': [427.02765, 158.91113],
#    'mouth_right': [447.8359, 193.22095],
#    'mouth_left': [467.5735, 190.16301]}}}

# %%
import matplotlib.pyplot as plt
faces = RetinaFace.extract_faces(img_path = "DSC_0003.JPG", align = True)
for face in faces:
    plt.imshow(face)
    plt.show()

# %%
from deepface import DeepFace
obj = DeepFace.verify("DSC_0003.JPG", "input_image.jpg"
          , model_name = 'ArcFace', detector_backend = 'retinaface')
print(obj["verified"])
# Out:
# True

# %%
obj
# Out:
# {'verified': True,
#  'distance': 0.4276229783818143,
#  'threshold': 0.68,
#  'model': 'ArcFace',
#  'detector_backend': 'retinaface',
#  'similarity_metric': 'cosine'}

# %%
cached_path()

# %%
from pathlib import Path
import wget
from urllib.parse import urlparse
import os

# %%
def get_cache_path():
    home = str(Path.home())
    general_cache_path = os.path.join(home, ".cache")
    os.makedirs(general_cache_path, exist_ok=True)
    cache_path = os.path.join(str(general_cache_path), "RetinaEye")
    return cache_path

CACHE_PATH = get_cache_path()

# %%
CACHE_PATH
# Out:
# 'C:\\Users\\RPAREPAL\\.cache\\RetinaEye'

# %%
Path.cwd()
os.path.join(Path.cwd(), "base_weights")
# Out:
# WindowsPath('C:/Users/RPAREPAL/practice/DL/Computer_Vision/Face_Recognition/Security_System_Cam')
